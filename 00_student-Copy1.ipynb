# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: Mariia Galdina
# * Student pace: full time
# * Scheduled project review date/time:
# * Instructor name: Rafael Carrasco
# * Blog post URL:

# %% [markdown]
# ## Reading information from files
# For this project I have the King County House Sales dataset. The dataset can be found in the file `"kc_house_data.csv"`
# First step for work with this data set is scrubbing data.

# %%
# import all libraries for work 
import os # for work with path/dir
import pandas as pd
from glob import glob

# %%
# read information from csv file
data = pd.read_csv("kc_house_data.csv") 
data
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
# sort data for check id
data.sort_values("id", axis = 0, ascending = True, 
                 inplace = True, na_position ='last') 
data
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 2495      1000102   4/22/2015  300000.0         6       3.00         2400
# 2494      1000102   9/16/2014  280000.0         6       3.00         2400
# 6729      1200019    5/8/2014  647500.0         4       1.75         2060
# 8404      1200021   8/11/2014  400000.0         3       1.00         1460
# 8800      2800031    4/1/2015  235000.0         3       1.00         1430
# ...           ...         ...       ...       ...        ...          ...
# 16723  9842300095   7/25/2014  365000.0         5       2.00         1600
# 3257   9842300485   3/11/2015  380000.0         2       1.00         1040
# 7614   9842300540   6/24/2014  339000.0         3       1.00         1100
# 20963  9895000040    7/3/2014  399900.0         2       1.75         1410
# 15937  9900000190  10/30/2014  268950.0         3       1.00         1320
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
data.duplicated(subset='id').sum()
# Out:
# 177

# %%
df = list(data[(data.duplicated(subset='id')==True)].sort_values("id")['id'])
pd.set_option('display.max_columns', 999)
df
# Out:
# [1000102,
#  7200179,
#  109200390,
#  123039336,
#  251300110,
#  302000375,
#  324000530,
#  526059224,
#  641900050,
#  643300040,
#  705730280,
#  722039087,
#  723049156,
#  726049190,
#  795000620,
#  795000620,
#  937000330,
#  1036400200,
#  1139600270,
#  1217000340,
#  1219000473,
#  1231000510,
#  1232000810,
#  1237500540,
#  1250201165,
#  1254200015,
#  1423049019,
#  1432400120,
#  1446403850,
#  1450100390,
#  1523049207,
#  1524079093,
#  1545800290,
#  1568100300,
#  1630700361,
#  1721801010,
#  1781500435,
#  1788800630,
#  1788900230,
#  1823049202,
#  1825069031,
#  1901600090,
#  1922059278,
#  1954420170,
#  1974300020,
#  1995200200,
#  2019200220,
#  2023049218,
#  2044500213,
#  2143700830,
#  2206700215,
#  2212200100,
#  2228900270,
#  2231500030,
#  2422049104,
#  2473380920,
#  2560801222,
#  2561340020,
#  2568300045,
#  2619920170,
#  2621600015,
#  2724049222,
#  2726049071,
#  2767602141,
#  2767603612,
#  2787460720,
#  2892700041,
#  3185600040,
# ...

# %%
data1 = data.loc[data['id'].isin(df)]
data1
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 2495      1000102   4/22/2015  300000.0         6       3.00         2400
# 2494      1000102   9/16/2014  280000.0         6       3.00         2400
# 16800     7200179  10/16/2014  150000.0         2       1.00          840
# 16801     7200179   4/24/2015  175000.0         2       1.00          840
# 11422   109200390  10/20/2014  250000.0         3       1.75         1480
# ...           ...         ...       ...       ...        ...          ...
# 6339   9828200460   6/27/2014  260000.0         2       1.00          700
# 15186  9834200305   2/10/2015  615000.0         3       1.00         1790
# 15185  9834200305   7/16/2014  350000.0         3       1.00         1790
# 1084   9834200885   7/17/2014  360000.0         4       2.50         2080
# 1085   9834200885   4/20/2015  550000.0         4       2.50         2080
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# ...

# %%
data.loc[]

# %%
pd.set_option('display.max_columns', 999)

# %%
# check data types in dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21597 entries, 2495 to 15937
# Data columns (total 21 columns):
# id               21597 non-null int64
# date             21597 non-null object
# price            21597 non-null float64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       19221 non-null float64
# view             21534 non-null float64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# sqft_basement    21597 non-null object
# yr_built         21597 non-null int64
# yr_renovated     17755 non-null float64
# zipcode          21597 non-null int64
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# ...

# %%
# checking if any value is NaN 
data.isnull().sum()
# Out:
# id                  0
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2376
# view               63
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3842
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %%
data.replace(to_replace=[''], value='0',inplace=True)
data
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 2495      1000102   4/22/2015  300000.0         6       3.00         2400
# 2494      1000102   9/16/2014  280000.0         6       3.00         2400
# 6729      1200019    5/8/2014  647500.0         4       1.75         2060
# 8404      1200021   8/11/2014  400000.0         3       1.00         1460
# 8800      2800031    4/1/2015  235000.0         3       1.00         1430
# ...           ...         ...       ...       ...        ...          ...
# 16723  9842300095   7/25/2014  365000.0         5       2.00         1600
# 3257   9842300485   3/11/2015  380000.0         2       1.00         1040
# 7614   9842300540   6/24/2014  339000.0         3       1.00         1100
# 20963  9895000040    7/3/2014  399900.0         2       1.75         1410
# 15937  9900000190  10/30/2014  268950.0         3       1.00         1320
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
data.isnull().sum()
# Out:
# id                  0
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2376
# view               63
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3842
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %%
data1 = data.loc[(data['yr_renovated']==data['yr_built'])]
#data2 = data[data['sqft_basement']=='?']
#data3 = data[data['sqft_basement']=='?']
data1
#data['sqft_basement'] = data['sqft_basement'].astype(str).astype(float)
#data
# Out:
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []
#
# [0 rows x 21 columns]

# %%
data2 = data.loc[(data['sqft_basement']!='0.0')&(data['sqft_basement'].astype(str)!='?')]
data2

# %%
# sort data for check id
data.sort_values("id", axis = 0, ascending = True, 
                 inplace = True, na_position ='last') 
data
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 2495      1000102   4/22/2015  300000.0         6       3.00         2400
# 2494      1000102   9/16/2014  280000.0         6       3.00         2400
# 6729      1200019    5/8/2014  647500.0         4       1.75         2060
# 8404      1200021   8/11/2014  400000.0         3       1.00         1460
# 8800      2800031    4/1/2015  235000.0         3       1.00         1430
# ...           ...         ...       ...       ...        ...          ...
# 16723  9842300095   7/25/2014  365000.0         5       2.00         1600
# 3257   9842300485   3/11/2015  380000.0         2       1.00         1040
# 7614   9842300540   6/24/2014  339000.0         3       1.00         1100
# 20963  9895000040    7/3/2014  399900.0         2       1.75         1410
# 15937  9900000190  10/30/2014  268950.0         3       1.00         1320
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
data2 = data.duplicated().any()
data2
# Out:
# False

# %%
# Out:
# id                  0
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2376
# view               63
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3842
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %%
data3 =

# %%
import seaborn as sns
sns.heatmap(data.isna(), cbar=False)

# %%
sns.heatmap(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-05db696a3a9b> in <module>
# ----> 1 sns.heatmap(data)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     515     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     516                           annot_kws, cbar, cbar_kws, xticklabels,
# --> 517                           yticklabels, mask)
#     518
#     519     # Add the pcolormesh kwargs here
#
# ~/opt/anaconda3/lib/python3.7/site-packages/seaborn/matrix.py in __init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
# ...

# %%
import missingno as msno

# %%
msno.bar(data.sample(1000))

# %%
sns.pairplot(data)
# Out:
# /Users/marigaldina/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:829: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /Users/marigaldina/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:830: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
categorical:
    floors
    waterfront
    view
    condition
    grade
    zip code
    yr_buildibg
    

numeric:
    price
    bedrooms
    bathrooms
    sqft_living
    sqft_lot
    sqft_above
    sqft_basement
    
    
id                  0
date                0
price               0
bedrooms            0
bathrooms           0
sqft_living         0
sqft_lot            0
floors              0
waterfront       2376
view               63
condition           0
grade               0
sqft_above          0
sqft_basement       0
yr_built            0
yr_renovated     3842
zipcode             0
lat                 0
long                0
sqft_living15       0
sqft_lot15          0
dtype: int64

# %%
sns.regplot(x='price',y='sqft_living', data=data)

# %%
import matlib.plot as plt
plt.figure(figsize=(18,18))
sns.heatmap(df.corr().abs(), annot=True);
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-0379ad5a8703> in <module>
# ----> 1 import matlib.plot as plt
#       2 plt.figure(figsize=(18,18))
#       3 sns.heatmap(df.corr().abs(), annot=True);
#
# ModuleNotFoundError: No module named 'matlib'

# %%
import statmodel.api as sm
ols = sm.OLS(y, X)
res = ols.fit()
plt.hist(res.residuals)
scs.shapiro(res.residuals)
# P > 0.05 fail to reject the null, hat they’re normal
resids = res.residuals
x_space = np.linspace(0, 1,len(resids))
plt.scatter(x_space, resids)
# normal distribution of the data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-54d3539d4783> in <module>
# ----> 1 import statmodel.api as sm
#       2 ols = sm.OLS(y, X)
#       3 res = ols.fit()
#       4 plt.hist(res.residuals)
#       5 scs.shapiro(res.residuals)
#
# ModuleNotFoundError: No module named 'statmodel'

# %%
plt.hist(data['sqft_lot'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-1cb0b02c396b> in <module>
# ----> 1 plt.hist(df['sqft_lot'])
#
# NameError: name 'plt' is not defined

# %%
plt.hist(data['log_sqft_living'], bins=50)
plt.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-11e20f755d21> in <module>
# ----> 1 plt.hist(data['log_sqft_living'], bins=50)
#       2 plt.show
#
# NameError: name 'plt' is not defined

# %%
from sklearn.preprocessing import StandardScaler
scaler =StandardScaler()

# %%
x_scaler = scaler.fit_transform(scaler)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-69e60cb2b2d8> in <module>
# ----> 1 x_scaler = scaler.fit_transform(scaler)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     551         if y is None:
#     552             # fit method of arity 1 (unsupervised transformation)
# --> 553             return self.fit(X, **fit_params).transform(X)
#     554         else:
#     555             # fit method of arity 2 (supervised transformation)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py in fit(self, X, y)
#     637         # Reset internal state before fitting
#     638         self._reset()
# --> 639         return self.partial_fit(X, y)
#     640
#     641     def partial_fit(self, X, y=None):
#
# ...

# %%
x
